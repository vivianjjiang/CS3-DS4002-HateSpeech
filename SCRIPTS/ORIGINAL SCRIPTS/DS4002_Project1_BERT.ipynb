# %%
from google.colab import files, drive
import os, shutil, pathlib

# Create your project structure
os.makedirs("SCRIPTS", exist_ok=True)
os.makedirs("DATA/processed", exist_ok=True)
os.makedirs("OUTPUT", exist_ok=True)

print("Upload your script 03_model_transformer.py")
uploaded = files.upload()  # choose your .py file
# Move it into SCRIPTS/
for name in uploaded:
    shutil.move(name, f"SCRIPTS/{name}")

print("Upload your labeled_data_clean.csv")
uploaded = files.upload()  # choose your CSV
for name in uploaded:
    shutil.move(name, "DATA/processed/labeled_data_clean.csv")

print("Files in project:")
# !find . -maxdepth 3 -type f -print
# Out:
# Upload your script 03_model_transformer.py
#      <input type="file" id="files-e66fd4c1-46af-4503-b086-cb23ad25b6ba" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e66fd4c1-46af-4503-b086-cb23ad25b6ba">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
# !python SCRIPTS/03_model_transformer.py \
  --input DATA/processed/labeled_data_clean.csv \
  --out_dir OUTPUT \
  --model_name roberta-base \
  --epochs 4 \
  --batch_size 16 \
  --lr 2e-5 \
  --max_length 128 \
  --seed 42 \
  --oversample \
  --use_focal_loss \
  --focal_gamma 2.0
# Out:
# 2025-09-24 22:43:13.307559: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-09-24 22:43:13.324481: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1758753793.345505    3973 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1758753793.351925    3973 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !zip -r OUTPUT.zip OUTPUT
# Out:
#   adding: OUTPUT/ (stored 0%)
#   adding: OUTPUT/transformer_classification_report.txt (deflated 54%)
#   adding: OUTPUT/model/ (stored 0%)
#   adding: OUTPUT/model/merges.txt (deflated 53%)
#   adding: OUTPUT/model/config.json (deflated 52%)
#   adding: OUTPUT/model/tokenizer_config.json (deflated 75%)
#   adding: OUTPUT/model/special_tokens_map.json (deflated 52%)
#   adding: OUTPUT/model/tokenizer.json (deflated 82%)
#   adding: OUTPUT/model/model.safetensors (deflated 12%)
#   adding: OUTPUT/model/vocab.json (deflated 59%)
#   adding: OUTPUT/model/training_args.bin (deflated 53%)
#   adding: OUTPUT/transformer_metrics.json (deflated 61%)
#   adding: OUTPUT/trainer/ (stored 0%)
#   adding: OUTPUT/trainer/checkpoint-7928/ (stored 0%)
#   adding: OUTPUT/trainer/checkpoint-7928/merges.txt (deflated 53%)
#   adding: OUTPUT/trainer/checkpoint-7928/rng_state.pth (deflated 26%)
#   adding: OUTPUT/trainer/checkpoint-7928/scaler.pt (deflated 64%)
# ...

# %%
files.download("OUTPUT.zip")
